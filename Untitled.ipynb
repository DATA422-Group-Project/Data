# %%
library(tidyverse)
library(dplyr)
library(skimr)
library(stringr)
library(rvest)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 4.1.1"
# -- Attaching packages --------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.4     v dplyr   1.0.7
# v tidyr   1.1.4     v stringr 1.4.0
# v readr   2.0.2     v forcats 0.5.1
#
# Warning message:
# "package 'tibble' was built under R version 4.1.1"
# Warning message:
# "package 'tidyr' was built under R version 4.1.1"
# Warning message:
# "package 'readr' was built under R version 4.1.1"
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#
#
# Attaching package: 'rvest'
#
#
# The following object is masked from 'package:readr':
#
#     guess_encoding

# %%
url_owid_survey <- "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"

covid_survey <- read_csv(url_owid_survey)
# Out:
# Rows: 121017 Columns: 65
#
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr   (4): iso_code, continent, location, tests_units
# dbl  (60): total_cases, new_cases, new_cases_smoothed, total_deaths, new_dea...
# date  (1): date
#
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
covid_df<-covid_survey %>% group_by(iso_code)%>%
    select(iso_code,location,total_vaccinations,people_vaccinated,people_fully_vaccinated,total_tests_per_thousand)
covid_df
# Out:
#        iso_code location    total_vaccinations people_vaccinated
# 1      AFG      Afghanistan NA                 NA
# 2      AFG      Afghanistan NA                 NA
# 3      AFG      Afghanistan NA                 NA
# 4      AFG      Afghanistan NA                 NA
# 5      AFG      Afghanistan NA                 NA
# 6      AFG      Afghanistan NA                 NA
# 7      AFG      Afghanistan NA                 NA
# 8      AFG      Afghanistan NA                 NA
# 9      AFG      Afghanistan NA                 NA
# 10     AFG      Afghanistan NA                 NA
# 11     AFG      Afghanistan NA                 NA
# 12     AFG      Afghanistan NA                 NA
# 13     AFG      Afghanistan NA                 NA
# 14     AFG      Afghanistan NA                 NA
# 15     AFG      Afghanistan NA                 NA
# 16     AFG      Afghanistan NA                 NA
# 17     AFG      Afghanistan NA                 NA
# ...

# %%
covid_vaccine<-covid_df %>% filter(!grepl("OWID_", iso_code))
covid_vaccine
# Out:
#        iso_code location    total_vaccinations people_vaccinated
# 1      AFG      Afghanistan NA                 NA
# 2      AFG      Afghanistan NA                 NA
# 3      AFG      Afghanistan NA                 NA
# 4      AFG      Afghanistan NA                 NA
# 5      AFG      Afghanistan NA                 NA
# 6      AFG      Afghanistan NA                 NA
# 7      AFG      Afghanistan NA                 NA
# 8      AFG      Afghanistan NA                 NA
# 9      AFG      Afghanistan NA                 NA
# 10     AFG      Afghanistan NA                 NA
# 11     AFG      Afghanistan NA                 NA
# 12     AFG      Afghanistan NA                 NA
# 13     AFG      Afghanistan NA                 NA
# 14     AFG      Afghanistan NA                 NA
# 15     AFG      Afghanistan NA                 NA
# 16     AFG      Afghanistan NA                 NA
# 17     AFG      Afghanistan NA                 NA
# ...

# %%
vaccine_data<-covid_vaccine %>%
    group_by(location, iso_code)%>%
    summarise_if(is.double, max)%>%
    mutate(half_vaccinated = (people_vaccinated - people_fully_vaccinated))%>%
    distinct() %>%
    slice()

# %%
vaccine_data
# Out:
#     location                        iso_code total_vaccinations
# 1   Afghanistan                     AFG      NA
# 2   Albania                         ALB      NA
# 3   Algeria                         DZA      NA
# 4   Andorra                         AND      NA
# 5   Angola                          AGO      NA
# 6   Anguilla                        AIA      NA
# 7   Antigua and Barbuda             ATG      NA
# 8   Argentina                       ARG      NA
# 9   Armenia                         ARM      NA
# 10  Aruba                           ABW      NA
# 11  Australia                       AUS      NA
# 12  Austria                         AUT      NA
# 13  Azerbaijan                      AZE      NA
# 14  Bahamas                         BHS      NA
# 15  Bahrain                         BHR      NA
# 16  Bangladesh                      BGD      NA
# 17  Barbados                        BRB      NA
# 18  Belarus                         BLR      NA
# ...
